# %%
import sqlite3
from flask import Flask, render_template, request, g, redirect, url_for

DATABASE = 'films.db'

db = sqlite3.connect(DATABASE)
cursor = db.cursor()

# %%
cursor.execute('''SELECT f1.film_name AS film1, f2.film_name AS film2, f1.release_year
FROM films f1
JOIN films f2 ON f1.release_year = f2.release_year AND f1.id != f2.id;
''')
cursor.fetchall()
# Out:
# [('Nick of time', '12 Monkeys', 1995),
#  ('Nick of time', 'Se7ven', 1995),
#  ('Radius', 'I, Tonya', 2017),
#  ('Radius', 'John Wick: Chapter II', 2017),
#  ('Radius', 'Money Heist', 2017),
#  ('Radius', 'Okja', 2017),
#  ('Radius', 'The Punisher', 2017),
#  ('Radius', 'The Shape of Water', 2017),
#  ('Kingdom', 'Black Mirror Bandersnatch', 2018),
#  ('Kingdom', 'KGF: Chapter 1', 2018),
#  ('Kingdom', 'Mard Ko Dard Nahi Hota', 2018),
#  ('Kingdom', 'Master Z', 2018),
#  ('Kingdom', 'Njan Prakashan', 2018),
#  ('Kingdom', 'Richard Says Goodbye', 2018),
#  ('Kingdom', 'Soni', 2018),
#  ('Kingdom', 'Stree', 2018),
#  ('Kingdom', 'Succession', 2018),
#  ('Ip Man 2', 'Shutter Island', 2010),
#  ('Ip Man 2', 'The Social Network', 2010),
#  ('Ip Man 2', 'Unstoppable', 2010),
#  ('Ip Man 3', 'Better Call Saul', 2015),
#  ('Ip Man 3', 'Daredevil', 2015),
#  ('Ip Man 3', 'The Hateful Eight', 2015),
#  ('Master Z', 'Black Mirror Bandersnatch', 2018),
#  ('Master Z', 'KGF: Chapter 1', 2018),
# ...

# %%
cursor.execute('''select * from films where rating >= 8''')
cursor.fetchall()
# Out:
# [(54, 'Sandhyaaraagam', 1989, '2020-12-01 00:00', 9.0, None),
#  (57, 'The Sting', 1973, '2020-12-01 00:00', 8.5, ''),
#  (63, 'Tropic Thunder', 2008, '2020-12-01 00:00', 8.0, None),
#  (67, 'Klaus', 2019, '2020-12-01 00:00', 8.0, None),
#  (68, 'Rain Man', 1988, '2020-12-01 00:00', 9.0, None),
#  (72, 'Prisoners', 2013, '2021-01-01 00:00', 8.5, None),
#  (73, 'Chernobyl', 2019, '2021-01-01 00:00', 9.0, None),
#  (77, '12 Monkeys', 1995, '2021-01-01 00:00', 8.25, None),
#  (79, 'Drishyam (2013)', 2013, '2021-01-01 00:00', 8.25, None),
#  (80, 'Drishyam 2', 2021, '2021-01-01 00:00', 8.25, None),
#  (84, 'Tenet', 2020, '2021-01-01 00:00', '', ''),
#  (92, 'Pulp Fiction', 1994, '2021-06-08 20:49', 8.5, None),
#  (93, 'Paths Of Glory', 1957, '2021-06-09 00:59', 8.0, None),
#  (95, 'Inglorious Basterds', 2009, '2021-06-10 17:09', 8.0, None),
#  (99, 'Njan Prakashan', 2018, '2021-06-28 19:49', 8.0, None),
#  (100, 'The Hateful Eight', 2015, '2021-06-30 02:08', 8.5, None),
# ...

# %%
cursor = db.cursor()
cursor.execute('''
    INSERT INTO films (film_name, release_year, watched_time, rating, review)
VALUES
    ('Sandhyaaraagam', 1989, '2020-12-01 00:00', 9, NULL),
    ('Nick of time', NULL, '2020-12-01 00:00', 6, NULL),
    ('Radius', 2017, '2020-12-01 00:00', 6, NULL),
    ('The Sting', NULL, '2020-12-01 00:00', 8.5, NULL),
    ('Kingdom', 2018, '2020-12-01 00:00', 7, NULL),
    ('Ip Man 2', 2010, '2020-12-01 00:00', 7.5, NULL),
    ('Ip Man 3', 2015, '2020-12-01 00:00', 6.5, NULL),
    ('Master Z', 2018, '2020-12-01 00:00', 6, NULL),
    ('Ip Man 4', 2019, '2020-12-01 00:00', 7, NULL),
    ('Tropic Thunder', 2008, '2020-12-01 00:00', 8, NULL),
    ('Blood and Bone', 2009, '2020-12-01 00:00', 6.35, NULL),
    ('The Night Manager', 2016, '2020-12-01 00:00', 7.75, NULL),
    ('Moneyball', 2011, '2020-12-01 00:00', 7.45, NULL),
    ('Klaus', 2019, '2020-12-01 00:00', 8, NULL),
    ('Rain Man', 1988, '2020-12-01 00:00', 9, NULL);

''')
db.commit()
cursor.close()

# %%
cursor = db.cursor()
cursor.execute('''
    INSERT INTO films (film_name, release_year, watched_time, rating, review)
VALUES
    ('Monsters, Inc.', 2001, '2021-01-01 00:00', 7.9, NULL),
    ('Master', NULL, '2021-01-01 00:00', 6, NULL),
    ('Fast 1', NULL, '2021-01-01 00:00', 6.5, NULL),
    ('Prisoners', 2013, '2021-01-01 00:00', 8.5, NULL),
    ('Chernobyl', 2019, '2021-01-01 00:00', 9, NULL),
    ('Normal People', NULL, '2021-01-01 00:00', 4, NULL),
    ('True Romance', 1993, '2021-01-01 00:00', 7.75, NULL),
    ('Predestination', 2014, '2021-01-01 00:00', 7.9, NULL),
    ('12 Monkeys', 1995, '2021-01-01 00:00', 8.25, NULL),
    ('Richard Says Goodbye', NULL, '2021-01-01 00:00', 6.75, NULL),
    ('Drishyam (2013)', 2013, '2021-01-01 00:00', 8.25, NULL),
    ('Drishyam 2', 2021, '2021-01-01 00:00', 8.25, NULL),
    ('The Cable Guy', 1996, '2021-01-01 00:00', 6.46, NULL),
    ('Sultan', 2016, '2021-01-01 00:00', 6, NULL),
    ('Andhagaaram', 2020, '2021-01-01 00:00', 7.5, NULL),
    ('Tenet', 2020, '2021-01-01 00:00', NULL, NULL),
    ('Nobody (2021)', 2021, '2021-01-01 00:00', 7.5, NULL),
    ('Karnan', 2021, '2021-01-01 00:00', 7.5, NULL);

''')
db.commit()
cursor.close()

# %%
cursor = db.cursor()
cursor.execute('''
    INSERT INTO films (film_name, release_year, watched_time, rating, review)
VALUES
    ('Exit(2019)', 2019, '2021-04-06 00:51', 7.5, NULL),
    ('Wendy and Lucy', 2008, '2021-04-06 02:36', 7.25, NULL),
    ('Natural Born Killers', 1994, '2021-06-06 00:17', 7.25, NULL),
    ('Mumbai Express', 2005, '2021-06-07 15:52', 7.25, NULL),
    ('Midnight Express', 1978, '2021-06-08 00:45', 7.6, NULL),
    ('Pulp Fiction', 1994, '2021-06-08 20:49', 8.5, NULL),
    ('Paths Of Glory', 1957, '2021-06-09 00:59', 8, NULL),
    ('Donnie Brasco', 1997, '2021-06-09 22:52', 7, NULL),
    ('Mission Impossible: Dead Reckoning - Part One', NULL, '2023-10-16 10:59', 7.3, NULL),
    ('Hostel Hudugaru Bekagiddare', NULL, '2023-10-16 21:26', 7, NULL),
    ('Leo', NULL, '2023-10-16 21:10', 6.5, NULL),
    ('Sapta Sagaradaache Ello - Side A', NULL, '2023-10-23 02:06', 8, NULL),
    ('A History Of Violence', 2005, '2023-10-23 18:54', 7, NULL),
    ('Nope', 2022, '2023-10-30 00:09', 8, NULL),
    ('Joker', 2019, '2023-11-05 13:34', 7.53, NULL),
    ('Jigarthanda', 2014, '2023-11-13 09:43', 8.3, NULL),
    ('Jigarthanda XX', NULL, '2023-11-13 13:11', 7.5, NULL),
    ('Sapta Sagaradaache Ello - Side B', NULL, '2023-11-13 17:11', 8, NULL),
    ('Jawan', NULL, '2023-11-17 22:01', 5, NULL),
    ('Paruthiveeran', 2007, '2023-11-30 01:31', 7.2, NULL),
    ('Irugapatru', NULL, '2023-12-04 03:31', 6, NULL),
    ('A Better Tomorrow', 1986, '2023-12-07 01:19', 8, NULL),
    ('A Better Tomorrow II', NULL, '2023-12-10 22:52', 7.5, NULL),
    ('Cry Macho', 2021, '2023-12-15 01:42', 6.25, NULL),
    ('Loki', 2021, '2023-12-18 03:22', 8, NULL),
    ('Miss Shetty Mr Polishetty', NULL, '2023-12-26 23:55', 7, NULL),
    ('Falimy', NULL, '2023-12-27 02:02', 7.5, NULL),
    ('Parking', NULL, '2023-12-30 20:26', 8, NULL),
    ('The Killer', NULL, '2023-12-30 22:29', 6.5, NULL),
    ('12th Fail', NULL, '2023-12-31 03:11', 8, NULL);

''')
db.commit()
cursor.close()

# %%
cursor = db.cursor()
cursor.execute('''
    INSERT INTO films (film_name, release_year, watched_time, rating, review)
VALUES
    ('Dada', 2023, '2024-02-03 02:01', 6.5, NULL),
    ('Sirf Ek Bandaa Kafi Hai', 2023, '2024-02-26 05:01', 8, NULL),
    ('Annapoorani', 2023, '2024-03-02 06:01', 6, NULL),
    ('Kaathal The Core', 2023, '2024-03-23 07:01', 8, NULL);
''')
db.commit()
cursor.close()

# %%
cursor = db.cursor()
cursor.execute('''
    DELETE FROM films;               
''')
db.commit()
cursor.close()

# %%
cursor = db.cursor()
df = cursor.execute("select * from films where rating > 8.5 and rating NOT IN ['']").fetchall()
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 2
#       1 cursor = db.cursor()
# ----> 2 df = cursor.execute("select * from films where rating > 8.5 and rating NOT IN ['']").fetchall()
#       3 print(df)
#
# OperationalError: no such table: ''

# %%
cursor = db.cursor()
duplicate_entries = cursor.execute("select id, film_name, watched_time, count(*) as no_of_entries from films group by film_name, watched_time having count(*) > 1").fetchall()
duplicate_entries
# Out:
# [(305, 'The Beekeeper', '2024-02-04 00:05', 44)]

# %%
cursor.execute('select min(id), count(*) from films group by film_name, watched_time having  count(*) > 1').fetchall()
# Out:
# []

# %%
#query to delete duplicate entries

cursor.execute("""delete from films where film_name in (select film_name from films group by film_name, watched_time having count(*)> 1) and id not in 
               (select min(id) from (select id from films group by film_name, watched_time having count(*) > 1) )""")

db.commit()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
